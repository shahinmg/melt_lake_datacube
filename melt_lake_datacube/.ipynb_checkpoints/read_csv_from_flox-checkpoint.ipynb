# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import matplotlib.dates as mdates

# %%
df = pd.read_csv('./surface_CW2019_lake_mean_da_asc_hv.nc')

# %%
df
# Out:
#                              time   lake  \
# 0      2019-01-06 20:47:13.068929    1.0
# 1      2019-01-06 20:47:13.068929    2.0
# 2      2019-01-06 20:47:13.068929    4.0
# 3      2019-01-06 20:47:13.068929    5.0
# 4      2019-01-06 20:47:13.068929    6.0
# ...                           ...    ...
# 30775  2019-12-26 20:47:03.222614  485.0
# 30776  2019-12-26 20:47:03.222614  487.0
# 30777  2019-12-26 20:47:03.222614  495.0
# 30778  2019-12-26 20:47:03.222614  995.0
# 30779  2019-12-26 20:47:03.222614  998.0
#
#                                                       id  \
# 0      S1A_IW_GRDH_1SDH_20190106T204700_20190106T2047...
# 1      S1A_IW_GRDH_1SDH_20190106T204700_20190106T2047...
# 2      S1A_IW_GRDH_1SDH_20190106T204700_20190106T2047...
# 3      S1A_IW_GRDH_1SDH_20190106T204700_20190106T2047...
# 4      S1A_IW_GRDH_1SDH_20190106T204700_20190106T2047...
# ...                                                  ...
# 30775  S1B_IW_GRDH_1SDH_20191226T204650_20191226T2047...
# 30776  S1B_IW_GRDH_1SDH_20191226T204650_20191226T2047...
# 30777  S1B_IW_GRDH_1SDH_20191226T204650_20191226T2047...
# 30778  S1B_IW_GRDH_1SDH_20191226T204650_20191226T2047...
# 30779  S1B_IW_GRDH_1SDH_20191226T204650_20191226T2047...
#
#                            end_datetime constellation  sar:center_frequency  \
# 0      2019-01-06 20:47:25.568162+00:00    Sentinel-1                 5.405
# 1      2019-01-06 20:47:25.568162+00:00    Sentinel-1                 5.405
# 2      2019-01-06 20:47:25.568162+00:00    Sentinel-1                 5.405
# 3      2019-01-06 20:47:25.568162+00:00    Sentinel-1                 5.405
# 4      2019-01-06 20:47:25.568162+00:00    Sentinel-1                 5.405
# ...                                 ...           ...                   ...
# 30775  2019-12-26 20:47:15.722007+00:00    Sentinel-1                 5.405
# 30776  2019-12-26 20:47:15.722007+00:00    Sentinel-1                 5.405
# 30777  2019-12-26 20:47:15.722007+00:00    Sentinel-1                 5.405
# 30778  2019-12-26 20:47:15.722007+00:00    Sentinel-1                 5.405
# 30779  2019-12-26 20:47:15.722007+00:00    Sentinel-1                 5.405
#
#        s1:processing_level                    start_datetime  s1:datatake_id  \
# 0                        1  2019-01-06 20:47:00.569695+00:00          184005
# 1                        1  2019-01-06 20:47:00.569695+00:00          184005
# 2                        1  2019-01-06 20:47:00.569695+00:00          184005
# 3                        1  2019-01-06 20:47:00.569695+00:00          184005
# 4                        1  2019-01-06 20:47:00.569695+00:00          184005
# ...                    ...                               ...             ...
# 30775                    1  2019-12-26 20:46:50.723221+00:00          151255
# 30776                    1  2019-12-26 20:46:50.723221+00:00          151255
# 30777                    1  2019-12-26 20:46:50.723221+00:00          151255
# 30778                    1  2019-12-26 20:46:50.723221+00:00          151255
# 30779                    1  2019-12-26 20:46:50.723221+00:00          151255
#
#        s1:total_slices  ...  sat:absolute_orbit  sar:resolution_azimuth  \
# 0                   17  ...               25362                      22
# 1                   17  ...               25362                      22
# 2                   17  ...               25362                      22
# 3                   17  ...               25362                      22
# 4                   17  ...               25362                      22
# ...                ...  ...                 ...                     ...
# 30775               17  ...               19541                      22
# 30776               17  ...               19541                      22
# 30777               17  ...               19541                      22
# 30778               17  ...               19541                      22
# 30779               17  ...               19541                      22
#
#        sar:observation_direction  \
# 0                          right
# 1                          right
# 2                          right
# 3                          right
# 4                          right
# ...                          ...
# 30775                      right
# 30776                      right
# 30777                      right
# 30778                      right
# 30779                      right
#
#                                              description  \
# 0      Terrain-corrected gamma naught values of signa...
# 1      Terrain-corrected gamma naught values of signa...
# 2      Terrain-corrected gamma naught values of signa...
# 3      Terrain-corrected gamma naught values of signa...
# 4      Terrain-corrected gamma naught values of signa...
# ...                                                  ...
# 30775  Terrain-corrected gamma naught values of signa...
# 30776  Terrain-corrected gamma naught values of signa...
# 30777  Terrain-corrected gamma naught values of signa...
# 30778  Terrain-corrected gamma naught values of signa...
# 30779  Terrain-corrected gamma naught values of signa...
#
#                                            title  \
# 0      HV: horizontal transmit, vertical receive
# 1      HV: horizontal transmit, vertical receive
# 2      HV: horizontal transmit, vertical receive
# 3      HV: horizontal transmit, vertical receive
# 4      HV: horizontal transmit, vertical receive
# ...                                          ...
# 30775  HV: horizontal transmit, vertical receive
# 30776  HV: horizontal transmit, vertical receive
# 30777  HV: horizontal transmit, vertical receive
# 30778  HV: horizontal transmit, vertical receive
# 30779  HV: horizontal transmit, vertical receive
#
#                                             raster:bands  epsg spatial_ref  \
# 0      {'nodata': -32768, 'data_type': 'float32', 'sp...  3413           0
# 1      {'nodata': -32768, 'data_type': 'float32', 'sp...  3413           0
# 2      {'nodata': -32768, 'data_type': 'float32', 'sp...  3413           0
# 3      {'nodata': -32768, 'data_type': 'float32', 'sp...  3413           0
# 4      {'nodata': -32768, 'data_type': 'float32', 'sp...  3413           0
# ...                                                  ...   ...         ...
# 30775  {'nodata': -32768, 'data_type': 'float32', 'sp...  3413           0
# 30776  {'nodata': -32768, 'data_type': 'float32', 'sp...  3413           0
# 30777  {'nodata': -32768, 'data_type': 'float32', 'sp...  3413           0
# 30778  {'nodata': -32768, 'data_type': 'float32', 'sp...  3413           0
# 30779  {'nodata': -32768, 'data_type': 'float32', 'sp...  3413           0
#
#        band stackstac-44729165358212edd225188a20e41ebc
# 0        hv                                   0.026772
# 1        hv                                   0.120722
# 2        hv                                   0.051163
# 3        hv                                   0.011605
# 4        hv                                   0.011600
# ...     ...                                        ...
# 30775    hv                                        NaN
# 30776    hv                                   0.038262
# 30777    hv                                   0.022764
# 30778    hv                                   0.011253
# 30779    hv                                   0.018233
#
# [30780 rows x 40 columns]

# %%
lake1 = df[df['lake'] == 1]
lake1 = lake1.iloc[:,[0,-1]].set_index('time').dropna()
lake1.index = pd.to_datetime(lake1.index)
ax = lake1.plot(legend=False)
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.set_ylabel('backscatter (dB)')
plt.savefig('./lake_1_backscatter.png',dpi=300)

# %%
lake_ids = np.unique(df.lake)
fig, ax = plt.subplots()
for lake_id in lake_ids:
    lake = df[df['lake'] == lake_id]
    lake = lake.iloc[:,[0,-1]].set_index('time').dropna()
    lake.index = pd.to_datetime(lake.index)
    lake.plot(legend=False,ax=ax)
    plt.close()

ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.set_ylabel('backscatter (dB)')
ax.set_title('100 km$^{2}$ CW Subset')
# Out:
# Text(0.5, 1.0, '100 km$^{2}$ CW Subset')

# %%
fig.savefig('./all_backscatter.png',dpi=300)

# %%
fig
